# %%
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path 

# Load the dataset
BASE_DIR = Path.cwd()
csv_path = BASE_DIR / "bank_loan_approval_time_dataset.csv"

df = pd.read_csv(csv_path)
df
# Out:
#      Application_ID  Applicant_Age  Applicant_Income  Credit_Score  \
# 0                 1             28            103706           566
# 1                 2             40             73816           374
# 2                 3             53             34940           599
# 3                 4             33             30167           802
# 4                 5             59             71053           491
# ..              ...            ...               ...           ...
# 295             296             62             85498           648
# 296             297             25            104749           578
# 297             298             46            118302           418
# 298             299             40             74186           451
# 299             300             48            111530           423
#
#      Loan_Amount Employment_Type Application_Channel Previous_Default  \
# 0        1285890        Salaried              Online              Yes
# 1         103328   Self-Employed              Online               No
# 2         600834        Salaried              Branch              Yes
# 3        1148787   Self-Employed              Branch               No
# 4         475190        Salaried               Agent              Yes
# ..           ...             ...                 ...              ...
# 295       143283        Business              Branch               No
# 296      1253551        Business               Agent               No
# 297       771191   Self-Employed              Online               No
# 298       760407        Salaried              Branch              Yes
# 299       602592   Self-Employed               Agent               No
#
#      Approval_Time_Days
# 0                    22
# 1                    10
# 2                    11
# 3                     8
# 4                    18
# ..                  ...
# 295                  12
# 296                  16
# 297                  17
# 298                   9
# 299                  16
#
# [300 rows x 9 columns]

# %%
# Calculating statistics for approval times
mean_time = df["Approval_Time_Days"].mean()
std_time = df["Approval_Time_Days"].std()
median_time = df["Approval_Time_Days"].median()
min_time = df["Approval_Time_Days"].min()
max_time = df["Approval_Time_Days"].max()

# %%
# Displaying the computed statistics
print("Mean Approval Time:", mean_time)
print("Standard Deviation:", std_time)
print("Median:", median_time)
print("Min:", min_time)
print("Max:", max_time)
# Out:
# Mean Approval Time: 13.88
# Standard Deviation: 4.72794297935725
# Median: 14.0
# Min: 1
# Max: 26

# %%
# Plotting the distribution of approval times
plt.hist( df["Approval_Time_Days"],
    bins=15,
    color="#43D857",
    edgecolor="black",
    alpha=0.85)
plt.xlabel("Approval Time (Days)")
plt.ylabel("Number of Applications")
plt.title("Distribution of Loan Approval Time")
plt.show()

# %%
# Identifying efficient vs delayed approvals
efficient = df[df["Approval_Time_Days"] <= 14]
delayed = df[df["Approval_Time_Days"] > 14]

print("Efficient approvals:", len(efficient))
print("Delayed approvals:", len(delayed))
# Out:
# Efficient approvals: 166
# Delayed approvals: 134
